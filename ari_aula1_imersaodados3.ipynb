# %% [markdown]
# <a href="https://colab.research.google.com/github/ariadnecs/imersao-dados-alura/blob/main/ari_aula1_imersaodados3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 Imersão dados
# github: https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip

# %%
import pandas as pd

url_dados= 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
# para plotar as cinco primeiras linhas
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# # Explorando Dados da Tabela

# %% [markdown]
# ## .shape

# %%
#para saber a quantidade de linhas e colunas da tabela
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# ## .unique()

# %%
# para visualizar valores únicos da coluna desejada
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
# tempo de exposição
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
# dados anonimizados
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
# valores normalizados relacionados ao gene 0 
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# #.value_counts()

# %%
# contar valores da coluna tratatmento, frequência absoluta
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tempo'].value_counts()
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# # Frequência Relativa
# ###.value_counts(normalize = TRUE)

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tempo'].value_counts(normalize = True)
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# #Gráficos feitos em aula

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# #Filtrando dados > 0

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0']> 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# #Desafio 01: Indique por que a classe 'tratamento' é tão desbalanceada.

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# É possível observar que os tratamentos com controle representam 7,83% dos valores amostrais.

# %%
dados['tratamento'].value_counts().plot.bar()
plt.ylabel('Quantidade')
plt.xlabel('Tratamentos')
plt.title('Tratamentos Amostras')
plt.show()

# %% [markdown]
# # Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
#Desafio 02: .tail()
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# # Desafio 03: Calcular a proporção das classes 'tratamento'

# %%
# Desafio 03
# Frequência relativa, calsses 'tratamento'

# para saber a quantidade de linhas e colunas
dados.shape

#frequências absoulutas
dados['tratamento'].value_counts()

#com droga
droga_fr = 21948 / 23813
controle_fr = 1866 / 23813
print(f'freqência relativa droga: {droga_fr:.3f} \nfrequência relativa controle: {controle_fr:.3f}')
# Out:
# freqência relativa droga: 0.922
# frequência relativa controle: 0.078

# %%
# frequência relativa das classes tratamento
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
#Desafio 04 Quantos tipos de drogas foram investigados?
dados['droga']
# Out:
# 0        b68db1d53
# 1        df89a8e5a
# 2        18bb41b2c
# 3        8c7f86626
# 4        7cbed3131
#            ...
# 23809    df1d0a5a1
# 23810    ecf3b6b74
# 23811    cacb2b860
# 23812    8b87a7a83
# 23813    972f41291
# Name: droga, Length: 23814, dtype: object

# %% [markdown]
# # Desafio 04: Quantos tipos de drogas foram investigados?

# %%
#Desafio 04
droga_id = dados[['droga']].drop_duplicates().set_index('droga')
print(f'Quantidade de drogas testadas: {droga_id.shape[0]}.')
# Out:
# Quantidade de drogas testadas: 3289.

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html?highlight=query#pandas.DataFrame.query

# %% [markdown]
# # Desafio 05: Procurar na documentação o método query() do pandas
#
# #####https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html
# #####-> Backtick quoted variables
# #####-> During parsing a number of disallowed characters inside the backtick quoted string are replaced by strings that are allowed as a Python identifier.

# %%
# Desafio 05: Procurar na documentação o método query() do pandas
dados.query('`g-0` == 0')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 894    id_090d5faab     com_droga     72   D1  ... -1.0650 -1.8200 -1.3260 -0.7249
# 1380   id_0e68cbbb8     com_droga     72   D2  ... -2.3280 -1.9860 -3.1180  0.4858
# 2201   id_1788469a3     com_droga     24   D1  ...  0.4966 -1.2220  0.9120 -0.1879
# 3585   id_267bbbda0     com_droga     24   D2  ...  0.6269 -0.1610 -0.7621  0.4061
# 4886   id_34a35a55c     com_droga     72   D2  ...  0.3130  0.2335  0.7553  0.9155
# 5595   id_3c3423a3d     com_droga     24   D1  ... -1.0190 -1.5860 -0.2275  0.8549
# 5667   id_3d03b67a9     com_droga     72   D1  ...  0.3007  0.8952  0.1277 -0.2204
# 6289   id_438f79667     com_droga     72   D2  ... -2.4300 -1.1520 -0.8239 -0.9811
# 8022   id_560168f5c     com_droga     48   D2  ... -0.2602 -0.9836 -0.0871 -0.3563
# 9338   id_644aee88b     com_droga     48   D1  ...  0.4707  1.1140  0.8708  0.7890
# ...

# %% [markdown]
# # Desafio 06: Renomear as colunas, retirando os hífens

# %%
# Desafio 06: Renomear as colunas, retirando os hífens
dados.columns = dados.columns.str.replace("-", "")
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# #Desafio 07: Organizar os gráficos com título, label (Matplotlib.pyplot)

# %%
import matplotlib.pyplot as plt
dados['tempo'].value_counts().plot.bar()
plt.ylabel('Quantidade')
plt.xlabel('Tempo')
plt.title('Tempo de cada tratamento')
plt.show()

# %%
dados['tratamento'].value_counts().plot.bar()
plt.ylabel('Quantidade')
plt.xlabel('Tratamentos')
plt.title('Tratamentos Amostras')
plt.show()

# %% [markdown]
# # Desafio 8: Faça um resumo do que você aprendeu hoje

# %% [markdown]
# ###Na aula 1 aprendemos a:
#
# *   Importar tabela utilizando a biblioteca pandas
# *   Explorar dados da tabela utilizando: shape, unique(), value_counts()
# *   Filtrar dados
# *   Plotar gráficos: pizza e barras
# *   Pesquisar método query()
